# %% [markdown]
# # Fantasy Football Analysis
# Utilizing the yahoo-fantasy-api, this notebook explores data from the fantasy football league to draw analytical conclusions.
#
# Start by pulling in the necessary libraries and generating OAuth2 configuration from Yahoo's API.

# %%
from yahoo_oauth import OAuth2
import yahoo_fantasy_api as yfa
# import yff
# import google_sheets as gs
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from bs4 import BeautifulSoup
import requests
import re
import difflib
# %matplotlib inline

from importlib import reload
# reload(gs)
# reload(yff)

rows = None
pd.set_option('display.max_row', rows)
pd.set_option('display.min_row', rows)


# oauth = OAuth2(None, None, from_file='yahoo.json')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\1/ipykernel_1640/3954206028.py in <module>
#       1 from yahoo_oauth import OAuth2
#       2 import yahoo_fantasy_api as yfa
# ----> 3 import yff
#       4 # import google_sheets as gs
#       5 import pandas as pd
#
# ModuleNotFoundError: No module named 'yff'

# %% [markdown]
# ## Explore 2020 Season

# %%
# reload(yff)

# Create season object
# ssn20 = yff.fantasy_season(oauth, 2020)

# %%
# ssn20.get_team_data('9')

# %% [markdown]
# ## Draft Prep
# Pull Player Data and Rankings From Various Websites

# %%
fteams = ['RK', '1.0', 'ES', 'AY', 'KA', 'BL', 'NG', 'RW', 'BM', 'JB', 'BD', '2.0']  # 2022 order

replacements = {'Pat Mahomes': 'Patrick Mahomes', 
                'Allen Robinson II': 'Allen Robinson',
                'D.K. Metcalf': 'DK Metcalf',
                'J.K. Dobbins': 'JK Dobbins',
                'D.J. Moore': 'DJ Moore',
                'A.J. Brown': 'AJ Brown',
                'A.J. Dillon': 'AJ Dillon',
                'Ben Roethlisberger PIT': 'Ben Roethlisberger',
                'D.J. Chark': 'DJ Chark',
                'DJ Chark Jr.': 'DJ Chark',
                'Darrell Henderson Jr.': 'Darrell Henderson',
                'J.D. McKissic': 'JD McKissic',
                'Justin Fields CHI': 'Justin Fields',
                'Kirk Cousins MIN': 'Kirk Cousins',
                'Marvin Jones Jr.': 'Marvin Jones',
                'Melvin Gordon III': 'Melvin Gordon',
                'Michael Pittman Jr.': 'Michael Pittman',
                'Odell Beckham Jr': 'Odell Beckham',
                'Odell Beckham Jr.': 'Odell Beckham',
                'Robert Tonyan Jr.': 'Robert Tonyan',
                'Ronald Jones II': 'Ronald Jones',
                'Teddy Birdgewater DEN': 'Teddy Birdgewater',
                'Trey Lance SF': 'Trey Lance',
                'Will Fuller V': 'Will Fuller',
                'Zack Wilson NYJ': 'Zach Wilson',
                'Brian Robinson Jr': 'Brian Robinson',
                'Darrell Henderson Jr': 'Darrell Henderson',
                'Irv Smith Jr': 'Irv Smith',
                'Isaih Pacheco': 'Isiah Pacheco',
                'Kenneth Walker III': 'Kenneth Walker',
                'Mark Ingram II': 'Mark Ingram',
                'Michael Pittman Jr': 'Michael Pittman',
                'Mitchell Trubisky': 'Mitch Trubisky',
                'Travis Etienne Jr': 'Travis Etienne'
                }

ffc_teams =    {'Carolina': 'CAR',
                'Kansas City': 'KC',
                'Minnesota': 'MIN',
                'New Orleans': 'NO',
                'Buffalo': 'BUF',
                'Tennessee': 'TEN',
                'Baltimore': 'BAL',
                'Dallas': 'DAL',
                'Arizona': 'ARI',
                'Green Bay': 'GB',
                'NY Giants': 'NYG',
                'Seattle': 'SEA',
                'LA Chargers': 'LAC',
                'Indianapolis': 'IND',
                'Cleveland': 'CLE',
                'Atlanta': 'ATL',
                'Washington': 'WAS',
                'Commanders': 'WAS',
                'Tampa Bay': 'TB',
                'Pittsburgh': 'PIT',
                'Cincinnati': 'CIN',
                'Las Vegas': 'LV',
                'Chicago': 'CHI',
                'San Francisco': 'SF',
                'LA Rams': 'LAR',
                'Detroit': 'DET',
                'Philadelphia': 'PHI',
                'Miami': 'MIA',
                'Jacksonville': 'JAX',
                'Denver': 'DEN',
                'NY Jets': 'NYJ',
                'New England': 'NE',
                'Houston': 'HOU'}

espn_teams =   {'Carolina Panthers': 'CAR',
                'Kansas City Chiefs': 'KC',
                'Minnesota Vikings': 'MIN',
                'New Orleans Saints': 'NO',
                'Buffalo Bills': 'BUF',
                'Tennessee Titans': 'TEN',
                'Baltimore Ravens': 'BAL',
                'Dallas Cowboys': 'DAL',
                'Arizona Cardinals': 'ARI',
                'Green Bay Packers': 'GB',
                'New York Giants': 'NYG',
                'Seattle Seahawks': 'SEA',
                'Los Angeles Chargers': 'LAC',
                'Indianapolis Colts': 'IND',
                'Cleveland Browns': 'CLE',
                'Atlanta Falcons': 'ATL',
                'Washington Football Team': 'WAS',
                'Washington Commanders': 'WAS',
                'Tampa Bay Buccaneers': 'TB',
                'Pittsburgh Steelers': 'PIT',
                'Cincinnati Bengals': 'CIN',
                'Las Vegas Raiders': 'LV',
                'Chicago Bears': 'CHI',
                'San Francisco 49ers': 'SF',
                'Los Angeles Rams': 'LAR',
                'Detroit Lions': 'DET',
                'Philadelphia Eagles': 'PHI',
                'Miami Dolphins': 'MIA',
                'Jacksonville Jaguars': 'JAX',
                'Denver Broncos': 'DEN',
                'New York Jets': 'NYJ',
                'New England Patriots': 'NE',
                'Houston Texans': 'HOU'}
sn_teams = {'Panthers': 'CAR',
            'Chiefs': 'KC',
            'Vikings': 'MIN',
            'Saints': 'NO',
            'Bills': 'BUF',
            'Titans': 'TEN',
            'Ravens': 'BAL',
            'Cowboys': 'DAL',
            'Cardinals': 'ARI',
            'Packers': 'GB',
            'Giants': 'NYG',
            'Seahawks': 'SEA',
            'Chargers': 'LAC',
            'Colts': 'IND',
            'Browns': 'CLE',
            'Falcons': 'ATL',
            'Washington': 'WAS',
            'Commanders': 'WAS',
            'Buccaneers': 'TB',
            'Steelers': 'PIT',
            'Bengals': 'CIN',
            'Raiders': 'LV',
            'Bears': 'CHI',
            '49ers': 'SF',
            'Rams': 'LAR',
            'Lions': 'DET',
            'Eagles': 'PHI',
            'Dolphins': 'MIA',
            'Jaguars': 'JAX',
            'Broncos': 'DEN',
            'Jets': 'NYJ',
            'Patriots': 'NE',
            'Texans': 'HOU'}

# %%
def ds_df():
    """Draft Sharks"""
    url = 'https://www.draftsharks.com/adp/superflex'
    ds = pd.read_html(url)[0]

    # Break up string
    ds['ds_rank'] = ds['Positional Rank'].str.split('.', n=1).str[0]
    ds['name_pos'] = ds['Positional Rank'].str.split('.', n=1).str[-1]

    reg_pat = r'^(.*)(QB|RB|WR|TE|DEF|K)$'
    ds[['name', 'pos']] = ds['name_pos'].str.extract(reg_pat)

    # Clean up strings
    for col in ['ds_rank', 'name', 'pos']:
        ds[col] = ds[col].str.strip()
    ds['ds_rank'] = ds['ds_rank'].astype(int)

    # Rename columns
    ds = ds.rename(lambda x: x.lower().replace(' ','_'), axis=1)

    # Pick necessary columns
    cols = ['ds_rank', 'name', 'pos', 'bye_week']
    ds = ds[cols]

    # Make position rank column
    pos_rank = ds.groupby('pos')['ds_rank'].rank().astype(int)
    ds['ds_pos'] = ds['pos'] + pos_rank.astype(str)

    # Drop position column
    ds = ds.drop('pos', axis=1)
    
    # Replace common characters
    ds['name'] = ds['name'].str.replace(r'\.', '', regex=True).str.strip()
    ds = ds.replace(replacements).replace(sn_teams).replace(espn_teams, regex=True)
    return ds

# ESPN
def espn_df():
    url = 'https://www.espn.com/fantasy/football/story/_/id/34058190/eric-karabell-fantasy-football-superflex-rankings-2022'
    req = requests.get(url)
    soup = BeautifulSoup(req.content)
    para = ["name", "team_posrank"]
    ls = soup.find_all('p')[3].text
    ls = re.split(r'\n', ls)  # remove newline characters
    df = pd.DataFrame([re.split(r'(?:\A\w+\.)|(?:,)', txt) for txt in ls]).drop(0, axis=1)
    df.columns = para
    df['name'] = df['name'].str.strip()
    df['team_posrank'] = df['team_posrank'].str.strip()

    reg_pat = r'^(\w*)\s*\((.*)\)$'
    df[['team', 'espn_pos']] = df['team_posrank'].str.extract(reg_pat)

    df = df.reset_index().rename({'index': 'espn_rank'}, axis=1)
    df['espn_rank'] = df['espn_rank'].astype(int) + 1
    df = df.drop('team_posrank', axis=1)

    # Replace common characters
    df['team'] = df['team'].str.upper()
    df['name'] = (df['name'].str.replace(r'\.', '', regex=True)
                            .str.strip()
                            .str.replace(r'\s*DST$', '', regex=True))
    df = df.replace(replacements).replace(sn_teams).replace(espn_teams, regex=True)
    return df

def rt_df():
    url = 'https://www.rototrade.com/rankings/2022/superflex/halfppr'
    req = requests.get(url)
    soup = BeautifulSoup(req.content)

    data = []
    for row in soup.find_all(attrs={'class': 'playerrow'}):
        row_data = []
        row_data.append(row.find('div', {'class': 'overallrank'}).text)
        row_data.append(row.find('div', {'class': 'name'}).text)
        row_data.append(row.find('div', {'class': 'pos'}).text)
        row_data.append(row.find('div', {'class': 'posandteam'}).text)
        data.append(row_data)

    rt = pd.DataFrame(data, columns=['rt_rank', 'name', 'rt_pos', 'team'])

    # Replace common characters
    rt['name'] = (rt['name'].str.replace(r'\.', '', regex=True)
                            .str.strip())
    rt['team'] = rt['team'].str.strip()
    rt = rt.replace(replacements).replace(sn_teams).replace(espn_teams, regex=True)
    return rt

def ffc_df():
    url = 'https://fantasyfootballcalculator.com/rankings/2qb'
    req = requests.get(url)
    soup = BeautifulSoup(req.content)
    cols = ['ffc_rank', 'name', 'team', 'pos', 'bye_week']
    rows = soup.find(attrs={'class': 'table table-striped mt-3'}).find("tbody").find_all("tr")

    # Read thru the table
    data = []
    for row in rows:
        data.append([val.text for val in row.find_all("td")])

    # Turn into dataframe
    ffc = pd.DataFrame(data, columns=cols)

    # Clean text and set types
    ffc['ffc_rank'] = ffc['ffc_rank'].str.replace('\.', '', regex=True).astype(int)
    ffc['bye_week'] = ffc['bye_week'].astype(int)
    for col in ['name', 'team', 'pos']:
        ffc[col] = ffc[col].str.strip()

    # Create pos rank
    pos_rank = ffc.groupby('pos')['ffc_rank'].rank().astype(int)
    ffc['ffc_pos'] = ffc['pos'] + pos_rank.astype(str)

    # Drop columns
    ffc = ffc.drop('pos', axis=1)

    # Replace common characters
    ffc['name'] = (ffc['name'].str.replace(r'\.', '', regex=True)
                              .str.replace(r'\s+Defense$', '', regex=True)
                              .str.strip())
    ffc = (ffc.replace(replacements)
              .replace(sn_teams)
              .replace(espn_teams, regex=True)
              .replace(ffc_teams, regex=True))
    
    return ffc

ffc = ffc_df()
rt = rt_df()
espn = espn_df()
ds = ds_df()

# %%
def gen_draft(ffc=ffc_df(), rt=rt_df(), espn=espn_df(), ds=ds_df()):
    # Merge
    df=(ffc.merge(rt, how='outer', on='name', suffixes=['_ffc', '_rt'])
        .merge(espn, how='outer', on='name', suffixes=[None, '_espn'])
        .merge(ds, how='outer', on='name', suffixes=[None, '_ds']))

    df['avg_rank'] = df[['ffc_rank', 'rt_rank', 'espn_rank', 'ds_rank']].mean(axis=1, numeric_only=True)
    df = df[['avg_rank', 'ffc_rank', 'rt_rank', 'espn_rank', 'ds_rank', 'name', 'ffc_pos', 'rt_pos', 'espn_pos', 'ds_pos',
            'team_ffc', 'team_rt', 'team', 'bye_week']].sort_values('avg_rank')

    # Clean cells
    int_cols = ['ffc_rank', 'rt_rank', 'espn_rank', 'ds_rank', 'bye_week']
    df[int_cols] = df[int_cols].astype('float').astype('Int32').astype(object)
    df = df.fillna('')  # Easier to read empty cells than NaNs

    def check_team(row):
        ffc = row['team_ffc']
        cbs = row['team_rt']
        espn = row['team']
        if len(ffc) > 1:
            return ffc
        if len(cbs) > 1:
            return cbs
        if len(espn) > 1:
            return espn

    def get_pos(row):
        ffc = row['ffc_pos']
        cbs = row['rt_pos']
        espn = row['espn_pos']
        sn = row['ds_pos']
        if len(ffc) > 1:
            return re.findall(r'(\D+)\d+', ffc)[0]
        if len(cbs) > 1:
            return re.findall(r'(\D+)\d+', cbs)[0]
        if len(espn) > 1:
            return re.findall(r'(\D+)\d+', espn)[0]
        else:
            return re.findall(r'(\D+)\d+', sn)[0]

    def replace_def(row):
        if row['pos'] == 'DST':
            row['team'] = row['name']

    # Clean up team columns
    df['team'] = df.apply(lambda row: check_team(row), axis=1)
    df = df.drop(['team_ffc', 'team_rt'], axis=1)

    # Clean up position columns
    pos_cols = ['ffc_pos', 'rt_pos', 'espn_pos', 'ds_pos']
    df[pos_cols] = df[pos_cols].replace({'DEF': 'DST', 'PK': 'K'}, regex=True)
    df['pos'] = df.apply(lambda row: get_pos(row), axis=1)

    # Clean up name column
    df['team'] = np.where(df['pos']=='DST', df['name'], df['team'])
    
    # Prepare for draft
    df['avg_rank'] = pd.to_numeric(df['avg_rank'], errors='coerce')
    df = df[['avg_rank', 'ffc_rank', 'rt_rank', 'espn_rank', 'ds_rank', 'pos', 'name', 'ffc_pos', 'rt_pos', 'espn_pos', 'ds_pos',
            'team', 'bye_week']].sort_values('avg_rank')

    df['avg_rank'] = df['avg_rank'].apply(lambda x: float("{:.1f}".format(x)))
    df['f_team'] = np.nan
    df['f_pick'] = np.nan

    return df

draft = gen_draft(ffc, rt, espn, ds)

# %%
dft = draft.copy()

# %%
pick_=0
def selection(pick, name, team, df=dft):
    if team not in fteams:
        raise ValueError('Team entered not in list')
    if name.lower() not in list(df['name'].str.lower()):
        print('WARNING: name entered not in draft list')
        print('Possible Options: {}'.format(difflib.get_close_matches(name, list(df['name']))))
        return df
    row = df[df['name'].str.match(name, case=False)]
    if len(row)>1:
        print('WARNING: Multiple name matches')
    idx = df.index[df['name'].str.fullmatch(name, case=False)][0]  # index location
    df.loc[idx,'f_team'] = team
    df.loc[idx,'f_pick'] = pick

    # Save file in case overwritten
    df.to_csv('stored_draft/2022_draft.csv')
    return df

def find_player(name, df=draft):
    name_list = list(df['name'])
    close_matches = difflib.get_close_matches(name, name_list, n=5)
    contains = [nm for nm in name_list if name in nm]
    print('Close Matches:\n{}'.format(close_matches))
    print('Contains:\n{}'.format(contains))

# %% [markdown]
# ## Analysis Section
# Use this section exclusively for analyzing data

# %%
# dft[dft['f_team']=='JB']
# dft[(dft['f_team'].isna()) & (dft['Pos']=='WR')].iloc[:40,:]
# dft[dft['f_team']=='KA']
dft[(dft['f_team'].isna())].iloc[:40,:]
# Out:
#     avg_rank ffc_rank rt_rank espn_rank ds_rank pos                 name  \
# 0        1.0        1       2         1       1  QB           Josh Allen
# 1        2.7        2       7         4       2  RB      Jonathan Taylor
# 2        3.0        3       9         3       3  QB       Justin Herbert
# 4        4.0        5       1         2       5  QB      Patrick Mahomes
# 3        7.7        4      12        15       4  RB  Christian McCaffrey
# 8        7.7        9       3         5       9  WR          Cooper Kupp
# 5        8.0        6      19        12       6  RB        Derrick Henry
# 6        8.3        7      10        11       7  RB        Austin Ekeler
# 7        8.3        8       4         9       8  WR     Justin Jefferson
# 9        8.7       10      20         6      10  QB        Lamar Jackson
# 10      12.0       11      21        14      11  RB         Najee Harris
# 14      12.0       15      17         7      14  QB         Kyler Murray
# 11      12.3       12      25        13      12  RB          Dalvin Cook
# 13      13.0       14       5        10      15  WR        Ja'Marr Chase
# 15      13.3       16      14         8      16  QB          Jalen Hurts
# 12      15.0       13      24        19      13  QB           Joe Burrow
# 16      19.0       17      15        23      17  RB            Joe Mixon
# 20      19.7       21      22        17      21  QB       Russell Wilson
# 17      20.7       18      32        26      18  RB        D'Andre Swift
# 19      22.3       20      28        27      20  WR         Stefon Diggs
# 18      22.7       19      11        30      19  WR        Davante Adams
# 25      23.3       26      13        16      28  QB            Tom Brady
# 22      24.0       23      26        24      25  RB         Alvin Kamara
# 21      25.3       22      54        32      22  TE         Travis Kelce
# 27      25.7       28      34        22      27  QB     Matthew Stafford
# 26      27.0       27      29        28      26  WR          CeeDee Lamb
# 30      27.3       31      18        20      31  QB         Dak Prescott
# 31      28.3       32       6        21      32  QB        Aaron Rodgers
# 33      28.7       34                18      34  QB           Trey Lance
# 24      29.0       25      16        39      23  RB           Nick Chubb
# 23      29.3       24      41        40      24  RB          Aaron Jones
# 29      29.7       30       8        29      30  WR         Deebo Samuel
# 35      33.0       36      30        25      38  RB     Javonte Williams
# 34      34.3       35      49        33      35  TE         Mark Andrews
# 36      34.7       37      23        31      36  WR          Tyreek Hill
# 32      36.3       33      47        43      33  RB    Leonard Fournette
# 37      36.3       38                34      37  QB           Derek Carr
# 28      36.7       29      36        52      29  RB       Saquon Barkley
# 41      40.7       42                38      42  QB         Kirk Cousins
# 38      41.7       39      35        47      39  WR           Mike Evans
#
#    ffc_pos rt_pos espn_pos ds_pos team bye_week  f_team  f_pick
# 0      QB1    QB2      QB1    QB1  BUF        7     NaN     NaN
# 1      RB1    RB1      RB1    RB1  IND       14     NaN     NaN
# 2      QB2    QB4      QB3    QB2  LAC        8     NaN     NaN
# 4      QB3    QB1      QB2    QB3   KC        8     NaN     NaN
# 3      RB2    RB3      RB6    RB2  CAR       13     NaN     NaN
# 8      WR2    WR1      WR1    WR2  LAR        7     NaN     NaN
# 5      RB3    RB6      RB3    RB3  TEN        6     NaN     NaN
# 6      RB4    RB2      RB2    RB4  LAC        8     NaN     NaN
# 7      WR1    WR2      WR2    WR1  MIN        7     NaN     NaN
# 9      QB4    QB9      QB4    QB4  BAL       10     NaN     NaN
# 10     RB5    RB7      RB5    RB5  PIT        9     NaN     NaN
# 14     QB6    QB7      QB5    QB6  ARI       13     NaN     NaN
# 11     RB6    RB8      RB4    RB6  MIN        7     NaN     NaN
# 13     WR3    WR3      WR3    WR3  CIN       10     NaN     NaN
# 15     QB7    QB6      QB6    QB7  PHI        7     NaN     NaN
# 12     QB5   QB11     QB10    QB5  CIN       10     NaN     NaN
# 16     RB7    RB4      RB7    RB7  CIN       10     NaN     NaN
# 20     QB8   QB10      QB8    QB8  DEN        9     NaN     NaN
# 17     RB8   RB11     RB10    RB8  DET        6     NaN     NaN
# 19     WR5    WR8      WR4    WR5  BUF        7     NaN     NaN
# 18     WR4    WR5      WR7    WR4   LV        6     NaN     NaN
# 25     QB9    QB5      QB7   QB10   TB       11     NaN     NaN
# 22     RB9    RB9      RB8   RB11   NO       14     NaN     NaN
# 21     TE1    TE4      TE1    TE1   KC        8     NaN     NaN
# 27    QB10   QB12     QB13    QB9  LAR        7     NaN     NaN
# 26     WR6    WR9      WR5    WR6  DAL        9     NaN     NaN
# 30    QB11    QB8     QB11   QB11  DAL        9     NaN     NaN
# 31    QB12    QB3     QB12   QB12   GB       14     NaN     NaN
# 33    QB13             QB9   QB13   SF        9     NaN     NaN
# 24    RB11    RB5     RB11    RB9  CLE        9     NaN     NaN
# 23    RB10   RB14     RB12   RB10   GB       14     NaN     NaN
# 29     WR7    WR4      WR6    WR7   SF        9     NaN     NaN
# 35    RB14   RB10      RB9   RB14  DEN        9     NaN     NaN
# 34     TE2    TE2      TE2    TE2  BAL       10     NaN     NaN
# 36     WR8    WR6      WR8    WR8  MIA       11     NaN     NaN
# 32    RB13   RB17     RB15   RB13   TB       11     NaN     NaN
# 37    QB14            QB14   QB14   LV        6     NaN     NaN
# 28    RB12   RB12     RB19   RB12  NYG        9     NaN     NaN
# 41    QB15            QB18   QB15  MIN        7     NaN     NaN
# 38     WR9   WR12     WR11    WR9   TB       11     NaN     NaN

# %% [markdown]
# ## Selection Section
# Use the following cell to generate and check selections

# %%
fteams = ['RK', '1.0', 'ES', 'AY', 'KA', 'BL', 'NG', 'RW', 'BM', 'JB', 'BD', '2.0']
class draft_controller:
    def __init__(self, pick=0, board=dft, auto_mode=False, rounds=20, backup=True):
        self.pick = int(pick)
        self.last_pick = {'name': '',
                          'fteam': '',
                          'pick': ''
                         }
        self.board = board
        self.auto_mode = auto_mode
        self.rounds = rounds
        self.backup = backup
        self.create_draft_list()

    def create_draft_list(self):
        d_list = fteams + list(reversed(fteams))
        d_list_reps = int(round(self.rounds / 2, 1))

        # Entire draft order fteams
        self.draft_order = d_list * d_list_reps

        # Entire draft order with tuples
        self.draft_order_tuples = [(ele, i) for i, ele in enumerate(self.draft_order, 1)]
        
        # Draft picks by owner
        d = {}
        for a, b in self.draft_order_tuples:
            if a in d:
                d[a].append(b)
            else:
                d[a] = [b]
        self.draft_picks = d

    def selection(self, name, pick=-1, fteam=''):
        # Copy board
        board = self.board.copy()

        if name.lower() not in list(self.board['name'].str.lower()):
            print('WARNING: name entered not in draft list')
            print('Possible Options: {}'.format(difflib.get_close_matches(name, list(self.board['name']))))
            return
        row = board[board['name'].str.match(name, case=False)]
        if len(row)>1:
            print('WARNING: Multiple name matches')
            return

        # If made it this far, look for auto_mode
        if self.auto_mode:
            self.pick += 1
            self.fteam = self.draft_order[self.pick-1]
        elif fteam not in fteams:
            raise ValueError('Team entered not in list')
        elif (pick < 0) | (pick > self.rounds*len(fteams)):
            raise ValueError('Please enter auto_mode of a valid pick number')
        elif fteam not in fteams:
            raise ValueError('Entered wrong fantasy team name')
        else:
            self.pick = pick
            self.fteam = fteam

        idx = board.index[board['name'].str.fullmatch(name, case=False)][0]  # index location
        board.loc[idx,'f_team'] = self.fteam
        board.loc[idx,'f_pick'] = self.pick

        self.board = board

        # Save file in case overwritten
        if self.backup:
            self.board.to_csv('stored_draft/2022_draft.csv')
        
        return self.board.copy()
        

drafter = draft_controller(auto_mode=True)
# drafter.auto_mode = True

# %%
drafter.draft_picks[jb]
# Out:
# [10,
#  15,
#  34,
#  39,
#  58,
#  63,
#  82,
#  87,
#  106,
#  111,
#  130,
#  135,
#  154,
#  159,
#  178,
#  183,
#  202,
#  207,
#  226,
#  231]

# %%
# selection(name, pick=-1, fteam='')

drafter.auto_mode = True
drafter.selection("Joe Mixon")
# Out:
#      avg_rank ffc_rank rt_rank espn_rank ds_rank  pos  \
# 0         1.0        1       2         1       1   QB
# 1         2.7        2       7         4       2   RB
# 2         3.0        3       9         3       3   QB
# 4         4.0        5       1         2       5   QB
# 3         7.7        4      12        15       4   RB
# 8         7.7        9       3         5       9   WR
# 5         8.0        6      19        12       6   RB
# 6         8.3        7      10        11       7   RB
# 7         8.3        8       4         9       8   WR
# 9         8.7       10      20         6      10   QB
# 10       12.0       11      21        14      11   RB
# 14       12.0       15      17         7      14   QB
# 11       12.3       12      25        13      12   RB
# 13       13.0       14       5        10      15   WR
# 15       13.3       16      14         8      16   QB
# 12       15.0       13      24        19      13   QB
# 16       19.0       17      15        23      17   RB
# 20       19.7       21      22        17      21   QB
# 17       20.7       18      32        26      18   RB
# 19       22.3       20      28        27      20   WR
# 18       22.7       19      11        30      19   WR
# 25       23.3       26      13        16      28   QB
# 22       24.0       23      26        24      25   RB
# 21       25.3       22      54        32      22   TE
# 27       25.7       28      34        22      27   QB
# 26       27.0       27      29        28      26   WR
# 30       27.3       31      18        20      31   QB
# 31       28.3       32       6        21      32   QB
# 33       28.7       34                18      34   QB
# 24       29.0       25      16        39      23   RB
# 23       29.3       24      41        40      24   RB
# 29       29.7       30       8        29      30   WR
# 35       33.0       36      30        25      38   RB
# 34       34.3       35      49        33      35   TE
# 36       34.7       37      23        31      36   WR
# 32       36.3       33      47        43      33   RB
# 37       36.3       38                34      37   QB
# 28       36.7       29      36        52      29   RB
# 41       40.7       42                38      42   QB
# 38       41.7       39      35        47      39   WR
# 42       42.3       43      64        41      43   RB
# 40       42.7       41      48        46      41   WR
# 39       43.7       40      62        51      40   RB
# 45       45.3       46      51        44      46   TE
# 47       47.0       48      31        45      48   WR
# 52       47.3       53                36      53   QB
# 46       48.0       47      73        50      47   RB
# 50       48.3       51      52        42      52   RB
# 48       49.0       49      42        49      49   RB
# 57       50.3       58                35      58   QB
# 43       50.7       44      44        64      44   WR
# 49       51.7       50                54      51   QB
# 44       52.0       45      27        66      45   WR
# 51       55.0       52      56        63      50   RB
# 55       56.3       56      45        57      56   TE
# 53       57.7       54      39        65      54   WR
# 56       58.3       57      57        59      59   RB
# 69       59.0       70                37      70   QB
# 54       59.7       55      69        69      55   WR
# 60       60.0       61      68        58      61   TE
# 59       60.3       60      40        61      60   RB
# 58       61.0       59      37        67      57   WR
# 66       62.3       67                53      67   QB
# 63       62.7       64      43        62      62   RB
# 61       65.0       62      38        70      63   WR
# 73       65.3       74      33        48      74   WR
# 65       66.7       66      53        68      66   WR
# 62       69.7       63      55        82      64   WR
# 77       71.3       78      65        60      76   RB
# 70       72.3       71      82        75      71   RB
# 64       74.0       65      72        92      65   RB
# 71       74.7       72      61        80      72   WR
# 68       75.0       69      46        87      69   WR
# 85       76.3       86                56      87   QB
# 75       76.3       76      77        78      75   RB
# 78       80.7       79      83        83      80   WR
# 72       82.7       73      59       102      73   WR
# 81       83.3       82                84      84   WR
# 76       84.0       77                97      78   WR
# 83       84.0       84                85      83   WR
# 67       84.3       68      76       117      68   WR
# 86       84.3       87      84        77      89   RB
# 82       85.0       83      90        90      82   RB
# 74       85.7       75               105      77   TE
# 84       85.7       85      63        86      86   WR
# 95       87.7       96                72      95   QB
# 93       87.7       94                76      93   RB
# 87       88.0       88      80        88      88   RB
# 80       88.0       81               104      79   TE
# 91       88.3       92      75        79      94   WR
# 98       89.3       99                71      98   QB
# 94       90.0       95                        85   QB
# 88       90.7       89      92        93      90   RB
# 79       90.7       80      88       111      81   RB
# 101      91.7      102                73     100   QB
# 90       93.7       91                99      91   WR
# 92       96.7       93      79       101      96   WR
# 102      98.3      103                89     103   RB
# 110      98.7      111                74     111   QB
# 122      99.7      123                55     121   QB
# 89      100.0       90      85       118      92   WR
# 104     101.7      105      50        96     104   WR
# 97      102.3       98      89       110      99   RB
# 108     102.3      109      91        91     107   RB
# 115     104.3      116      74        81     116   WR
# 100     104.7      101      78       112     101   RB
# 103     105.3      104      60       106     106   WR
# 99      105.7      100               115     102   WR
# 159     106.0               66       103     109   TE
# 107     108.0      108                             TE
# 105     108.0      106      70       113     105   WR
# 114     108.7      115                94     117   QB
# 113     109.7      114      58       100     115   WR
# 112     111.3      113               109     112   RB
# 106     112.7      107               123     108   TE
# 96      113.0       97      93       145      97   TE
# 125     115.7      126                95     126   QB
# 109     117.0      110      95       131     110   RB
# 126     117.7      127                98     128   WR
# 118     118.0      119      86       116     119   WR
# 111     120.7      112      67       137     113   WR
# 124     120.7      125      98       114     123   RB
# 117     121.0      118               127     118   QB
# 121     121.7      122      99       119     124   WR
# 119     124.3      120               133     120   RB
# 167     126.0                        126           QB
# 127     126.3      128               121     130   WR
# 116     128.0      117               153     114   RB
# 130     129.0      131               124     132   TE
# 168     130.0                        130           QB
# 131     130.0      132               129     129   QB
# 140     130.0      141      71       107     142   WR
# 128     132.7      129               142     127   RB
# 123     133.3      124      81       154     122   RB
# 120     133.7      121               155     125  DST
# 139     134.0      140               125     137   TE
# 137     137.7      138               135     140   RB
# 166     138.5                        120     157   WR
# 141     139.0      142               136     139   RB
# 142     139.3      143               128     147   QB
# 129     140.3      130               160     131   WR
# 135     140.7      136               148     138   TE
# 132     140.7      133               156     133  DST
# 165     142.5                        108     177   WR
# 146     143.0      147               138     144   WR
# 149     143.0      150               144     135   RB
# 157     146.0      158                       134   QB
# 153     146.0      154               134     150   RB
# 144     146.5      145                       148   WR
# 133     147.0      134               171     136   WR
# 145     147.3      146               143     153   RB
# 138     147.3      139               157     146  DST
# 143     148.0      144                       152   WR
# 152     148.3      153               151     141   RB
# 136     150.7      137               170     145   RB
# 172     152.0                        141     163   RB
# 148     152.0      149                       155   RB
# 151     154.0      152                       156  DST
# 173     156.5                        146     167   TE
# 134     157.3      135               194     143    K
# 163     157.5               97       147     168   TE
# 170     159.0                        139     179   WR
# 185     159.5                        168     151   RB
# 158     160.5      159                       162   WR
# 210     161.0                                161   TE
# 175     161.0                        150     172   QB
# 179     161.0                        161           WR
# 180     163.0                        163           WR
# 211     164.0                                164   TE
# 212     165.0                                165  DST
# 147     165.0      148               193     154    K
# 150     165.0      151               195     149    K
# 182     165.0                        165           WR
# 183     166.0                        166           RB
# 171     166.0                        140     192   WR
# 213     166.0                                166  DST
# 177     166.0                        158     174  DST
# 169     166.5                        132     201   RB
# 154     166.7      155               187     158  DST
# 164     167.0              100       122     212   WR
# 214     169.0                                169    K
# 186     169.0                        169           RB
# 156     169.7      157               192     160    K
# 155     170.7      156               197     159    K
# 215     171.0                                171   WR
# 174     171.5                        149     194   QB
# 194     174.5                        179     170   RB
# 216     175.0                                175  DST
# 190     175.0                        175           WR
# 192     175.0                        177     173   WR
# 217     176.0                                176  DST
# 191     176.0                        176           WR
# 178     178.5                        159     198  DST
# 187     179.0                        172     186   WR
# 195     180.0                        180           RB
# 196     181.0                        181           RB
# 161     181.0               94       162     200   WR
# 188     181.5                        173     190   WR
# 218     182.0                                182   WR
# 219     183.0                                183    K
# 198     184.0                        183     185   RB
# 203     184.5                        189     180  DST
# 189     185.0                        174     196   WR
# 200     185.0                        185           RB
# 193     185.5                        178     193   RB
# 202     186.0                        188     184  DST
# 220     187.0                                187   WR
# 184     187.0                        167     207   RB
# 201     187.0                        186     188  DST
# 176     188.0                        152     224   RB
# 208     188.5                        199     178    K
# 206     188.5                        196     181    K
# 221     189.0                                189    K
# 204     190.0                        190          DST
# 205     191.0                        191            K
# 222     191.0                                191   TE
# 223     195.0                                195  DST
# 181     195.0                        164     226   WR
# 224     197.0                                197    K
# 207     198.5                        198     199    K
# 197     199.5                        182     217   RB
# 225     202.0                                202    K
# 226     203.0                                203  DST
# 227     204.0                                204    K
# 228     205.0                                205  DST
# 209     205.0                        200     210    K
# 160     206.0               87               206   WR
# 199     206.0                        184     228   RB
# 229     208.0                                208    K
# 230     209.0                                209   WR
# 231     211.0                                211    K
# 232     213.0                                213   RB
# 233     214.0                                214   WR
# 234     215.0                                215   RB
# 235     216.0                                216   WR
# 236     218.0                                218    K
# 237     219.0                                219   TE
# 238     220.0                                220   TE
# 239     221.0                                221   TE
# 240     222.0                                222   RB
# 241     223.0                                223   TE
# 242     225.0                                225   RB
# 243     227.0                                227   TE
# 244     229.0                                229   WR
# 162       NaN               96                     WR
#
#                          name ffc_pos rt_pos espn_pos ds_pos  team bye_week  \
# 0                  Josh Allen     QB1    QB2      QB1    QB1   BUF        7
# 1             Jonathan Taylor     RB1    RB1      RB1    RB1   IND       14
# 2              Justin Herbert     QB2    QB4      QB3    QB2   LAC        8
# 4             Patrick Mahomes     QB3    QB1      QB2    QB3    KC        8
# 3         Christian McCaffrey     RB2    RB3      RB6    RB2   CAR       13
# 8                 Cooper Kupp     WR2    WR1      WR1    WR2   LAR        7
# 5               Derrick Henry     RB3    RB6      RB3    RB3   TEN        6
# 6               Austin Ekeler     RB4    RB2      RB2    RB4   LAC        8
# 7            Justin Jefferson     WR1    WR2      WR2    WR1   MIN        7
# 9               Lamar Jackson     QB4    QB9      QB4    QB4   BAL       10
# 10               Najee Harris     RB5    RB7      RB5    RB5   PIT        9
# 14               Kyler Murray     QB6    QB7      QB5    QB6   ARI       13
# 11                Dalvin Cook     RB6    RB8      RB4    RB6   MIN        7
# 13              Ja'Marr Chase     WR3    WR3      WR3    WR3   CIN       10
# 15                Jalen Hurts     QB7    QB6      QB6    QB7   PHI        7
# 12                 Joe Burrow     QB5   QB11     QB10    QB5   CIN       10
# 16                  Joe Mixon     RB7    RB4      RB7    RB7   CIN       10
# 20             Russell Wilson     QB8   QB10      QB8    QB8   DEN        9
# 17              D'Andre Swift     RB8   RB11     RB10    RB8   DET        6
# 19               Stefon Diggs     WR5    WR8      WR4    WR5   BUF        7
# 18              Davante Adams     WR4    WR5      WR7    WR4    LV        6
# 25                  Tom Brady     QB9    QB5      QB7   QB10    TB       11
# 22               Alvin Kamara     RB9    RB9      RB8   RB11    NO       14
# 21               Travis Kelce     TE1    TE4      TE1    TE1    KC        8
# 27           Matthew Stafford    QB10   QB12     QB13    QB9   LAR        7
# 26                CeeDee Lamb     WR6    WR9      WR5    WR6   DAL        9
# 30               Dak Prescott    QB11    QB8     QB11   QB11   DAL        9
# 31              Aaron Rodgers    QB12    QB3     QB12   QB12    GB       14
# 33                 Trey Lance    QB13             QB9   QB13    SF        9
# 24                 Nick Chubb    RB11    RB5     RB11    RB9   CLE        9
# 23                Aaron Jones    RB10   RB14     RB12   RB10    GB       14
# 29               Deebo Samuel     WR7    WR4      WR6    WR7    SF        9
# 35           Javonte Williams    RB14   RB10      RB9   RB14   DEN        9
# 34               Mark Andrews     TE2    TE2      TE2    TE2   BAL       10
# 36                Tyreek Hill     WR8    WR6      WR8    WR8   MIA       11
# 32          Leonard Fournette    RB13   RB17     RB15   RB13    TB       11
# 37                 Derek Carr    QB14            QB14   QB14    LV        6
# 28             Saquon Barkley    RB12   RB12     RB19   RB12   NYG        9
# 41               Kirk Cousins    QB15            QB18   QB15   MIN        7
# 38                 Mike Evans     WR9   WR12     WR11    WR9    TB       11
# 42               James Conner    RB16   RB22     RB13   RB16   ARI       13
# 40               Keenan Allen    WR10   WR18     WR10   WR10   LAC        8
# 39            Ezekiel Elliott    RB15   RB21     RB18   RB15   DAL        9
# 45                 Kyle Pitts     TE3    TE3      TE3    TE3   ATL       14
# 47                Tee Higgins    WR13   WR10      WR9   WR13   CIN       10
# 52             Tua Tagovailoa    QB17            QB16   QB17   MIA       11
# 46             Travis Etienne    RB17   RB26     RB17   RB17   JAX       11
# 50                  Cam Akers    RB19   RB18     RB14   RB20   LAR        7
# 48           David Montgomery    RB18   RB15     RB16   RB18   CHI       14
# 57            Trevor Lawrence    QB18            QB15   QB18   JAX       11
# 43            Michael Pittman    WR11   WR16     WR13   WR11   IND       14
# 49                  Matt Ryan    QB16            QB20   QB16   IND       14
# 44                   AJ Brown    WR12    WR7     WR15   WR12   PHI        7
# 51                 JK Dobbins    RB20   RB19     RB24   RB19   BAL       10
# 55              George Kittle     TE4    TE1      TE4    TE4    SF        9
# 53             Terry McLaurin    WR14   WR15     WR14   WR14   WAS       14
# 56                Breece Hall    RB21   RB20     RB20   RB21   NYJ       10
# 69              Justin Fields    QB20            QB17   QB20   CHI       14
# 54              Mike Williams    WR15   WR28     WR18   WR15   LAC        8
# 60              Darren Waller     TE5    TE6      TE5    TE5    LV        6
# 59            Elijah Mitchell    RB22   RB13     RB22   RB22    SF        9
# 58                 DK Metcalf    WR16   WR13     WR16   WR16   SEA       11
# 66             Jameis Winston    QB19            QB19   QB19    NO       14
# 63                Josh Jacobs    RB23   RB16     RB23   RB23    LV        6
# 61            Diontae Johnson    WR17   WR14     WR19   WR17   PIT        9
# 73                   DJ Moore    WR24   WR11     WR12   WR24   CAR       13
# 65              Jaylen Waddle    WR19   WR20     WR17   WR19   MIA       11
# 62           Courtland Sutton    WR18   WR21     WR23   WR18   DEN        9
# 77             Antonio Gibson    RB27   RB23     RB21   RB27   WAS       14
# 70      Clyde Edwards-Helaire    RB25   RB31     RB25   RB25    KC        8
# 64                  AJ Dillon    RB24   RB25     RB33   RB24    GB       14
# 71              Brandin Cooks    WR22   WR25     WR21   WR22   HOU        6
# 68               Chris Godwin    WR21   WR17     WR28   WR21    TB       11
# 85             Ryan Tannehill    QB21            QB22   QB22   TEN        6
# 75              Miles Sanders    RB26   RB27     RB28   RB26   PHI        7
# 78                Jerry Jeudy    WR26   WR34     WR24   WR26   DEN        9
# 72             Allen Robinson    WR23   WR23     WR35   WR23   LAR        7
# 81              Gabriel Davis    WR27            WR25   WR28   BUF        7
# 76               Adam Thielen    WR25            WR30   WR25   MIN        7
# 83             Darnell Mooney    WR28            WR26   WR27   CHI       14
# 67             Michael Thomas    WR20   WR32     WR41   WR20    NO       14
# 86                Kareem Hunt    RB30   RB32     RB27   RB31   CLE        9
# 82               Tony Pollard    RB29   RB35     RB31   RB29   DAL        9
# 74             Dalton Schultz     TE6             TE8    TE6   DAL        9
# 84             Marquise Brown    WR29   WR26     WR27   WR29   ARI       13
# 95               Daniel Jones    QB23            QB24   QB23   NYG        9
# 93           Devin Singletary    RB33            RB26   RB33   BUF        7
# 87              Damien Harris    RB31   RB29     RB29   RB30    NE       10
# 80               TJ Hockenson     TE7             TE7    TE7   DET        6
# 91           Amon-Ra St Brown    WR32   WR31     WR20   WR32   DET        6
# 98                  Mac Jones    QB24            QB23   QB24    NE       10
# 94             Deshaun Watson    QB22                   QB21   CLE        9
# 88              Chase Edmonds    RB32   RB37     RB34   RB32   MIA       11
# 79              Rashaad Penny    RB28   RB33     RB37   RB28   SEA       11
# 101              Carson Wentz    QB25            QB25   QB25   WAS       14
# 90             Hunter Renfrow    WR31            WR32   WR30    LV        6
# 92        JuJu Smith-Schuster    WR33   WR33     WR34   WR33    KC        8
# 102             Dameon Pierce    RB36            RB30   RB36   HOU        6
# 110                Jared Goff    QB26            QB26   QB26   DET        6
# 122               Zach Wilson    QB29            QB21   QB29   NYJ       10
# 89            DeAndre Hopkins    WR30   WR35     WR42   WR31   ARI       13
# 104              Amari Cooper    WR36   WR19     WR29   WR35   CLE        9
# 97        Rhamondre Stevenson    RB34   RB34     RB36   RB34    NE       10
# 108             Melvin Gordon    RB37   RB36     RB32   RB38   DEN        9
# 115              Elijah Moore    WR40   WR30     WR22   WR39   NYJ       10
# 100            Kenneth Walker    RB35   RB28     RB38   RB35   SEA       11
# 103            Rashod Bateman    WR35   WR24     WR36   WR36   BAL       10
# 99               Allen Lazard    WR34            WR39   WR34    GB       14
# 159            Dallas Goedert            TE5      TE6   TE10   PHI
# 107               DAL Goedert    TE10                          PHI        7
# 105     Cordarrelle Patterson    WR37   RB24     RB39   RB37   ATL       14
# 114            Baker Mayfield    QB27            QB27   QB27   CAR       13
# 113             DeVonta Smith    WR39   WR22     WR33   WR38   PHI        7
# 112            James Robinson    RB39            RB35   RB40   JAX       11
# 106                 Zach Ertz     TE9             TE9    TE9   ARI       13
# 96                Dawson Knox     TE8    TE7     TE12    TE8   BUF        7
# 125               Davis Mills    QB30            QB28   QB30   HOU        6
# 109                James Cook    RB38   RB38     RB41   RB39   BUF        7
# 126            Christian Kirk    WR43            WR31   WR42   JAX       11
# 118              Robert Woods    WR41   WR36     WR40   WR40   TEN        6
# 111             Brandon Aiyuk    WR38   WR27     WR47   WR37    SF        9
# 124            Michael Carter    RB43   RB39     RB40   RB44   NYJ       10
# 117            Marcus Mariota    QB28            QB30   QB28   ATL       14
# 121              Drake London    WR42   WR40     WR43   WR41   ATL       14
# 119              Nyheim Hines    RB41            RB43   RB42   IND       14
# 167                 Drew Lock                    QB29          SEA
# 127               Chris Olave    WR44            WR45   WR43    NO       14
# 116        Alexander Mattison    RB40            RB53   RB41   MIN        7
# 130            Pat Freiermuth    TE11            TE10   TE11   PIT        9
# 168            Desmond Ridder                    QB33          ATL
# 131            Mitch Trubisky    QB31            QB32   QB31   PIT        9
# 140             Tyler Lockett    WR47   WR29     WR37   WR46   SEA       11
# 128            Tyler Allgeier    RB44            RB48   RB45   ATL       14
# 123         Darrell Henderson    RB42   RB30     RB54   RB43   LAR        7
# 120                       BUF    DST1            DST1   DST1   BUF        7
# 139              Mike Gesicki    TE13            TE11   TE12   MIA       11
# 137            Raheem Mostert    RB46            RB45   RB48   MIA       11
# 166             Treylon Burks                    WR44   WR50   TEN
# 141            Isaiah Spiller    RB47            RB46   RB47   LAC        8
# 142             Kenny Pickett    QB32            QB31   QB33   PIT        9
# 129            Kadarius Toney    WR45            WR51   WR44   NYG        9
# 135                 Cole Kmet    TE12            TE15   TE13   CHI       14
# 132                        TB    DST2            DST2   DST2    TB       11
# 165            Chase Claypool                    WR38   WR54   PIT
# 146              Russell Gage    WR50            WR48   WR47    TB       11
# 149              Ronald Jones    RB50            RB50   RB46    KC        8
# 157           Jimmy Garoppolo    QB33                   QB32    SF        9
# 153               JD McKissic    RB52            RB44   RB51   WAS       14
# 144            Michael Gallup    WR49                   WR48   DAL        9
# 133                Skyy Moore    WR46            WR57   WR45    KC        8
# 145          Kenneth Gainwell    RB48            RB49   RB53   PHI        7
# 138                       LAR    DST3            DST3   DST3   LAR        7
# 143            George Pickens    WR48                   WR49   PIT        9
# 152               Marlon Mack    RB51            RB51   RB49   HOU        6
# 136            Brian Robinson    RB45            RB59   RB50   WAS       14
# 172             Rachaad White                    RB47   RB55    TB
# 148             Isiah Pacheco    RB49                   RB54    KC        8
# 151                        SF    DST4                   DST4    SF        9
# 173                 Irv Smith                    TE13   TE16   MIN
# 134             Justin Tucker      K1              K4     K1   BAL       10
# 163              Hunter Henry            TE8     TE14   TE17    NE
# 170  Marquez Valdes-Scantling                    WR49   WR55    KC
# 185               Mark Ingram                    RB57   RB52    NO
# 158               Julio Jones    WR51                   WR51    TB       11
# 210               David Njoku                           TE14  None
# 175           Jacoby Brissett                    QB35   QB34   CLE
# 179             Jakobi Meyers                    WR52           NE
# 180           Robbie Anderson                    WR54          CAR
# 211             Robert Tonyan                           TE15  None
# 212                       DAL                           DST6   DAL
# 147           Harrison Butker      K2              K3     K3    KC        8
# 150                Tyler Bass      K3              K5     K2   BUF        7
# 182           Marvin Jones Jr                    WR56          JAX
# 183           Damien Williams                    RB55          ATL
# 171            Mecole Hardman                    WR50   WR60    KC
# 213                       IND                           DST7   IND
# 177                        NO                    DST4   DST8    NO
# 169           Jamaal Williams                    RB42   RB59   DET
# 154                       PIT    DST5            DST7   DST5   PIT        9
# 164            Garrett Wilson           WR41     WR46   WR65   NYJ
# 214             Chris Boswell                             K6  None
# 186            Khalil Herbert                    RB58          CHI
# 156                  Matt Gay      K5              K2     K5   LAR        7
# 155            Daniel Carlson      K4              K7     K4    LV        6
# 215               Romeo Doubs                           WR52  None
# 174                Geno Smith                    QB34   QB35   SEA
# 194            D'Onta Foreman                    RB61   RB56   CAR
# 216                       WAS                           DST9   WAS
# 190             Van Jefferson                    WR61          LAR
# 192                  DJ Chark                    WR63   WR53   DET
# 217                       LAC                          DST10   LAC
# 191             Joshua Palmer                    WR62          LAC
# 178                        GB                    DST5  DST15    GB
# 187              Jahan Dotson                    WR58   WR57   WSH
# 195              Rex Burkhead                    RB62          HOU
# 196                Mike Davis                    RB63          BAL
# 161                Tyler Boyd           WR38     WR53   WR62   CIN
# 188             Jarvis Landry                    WR59   WR59    NO
# 218             Jalen Tolbert                           WR56  None
# 219             Jason Sanders                             K9  None
# 198               Zamir White                    RB65   RB57    LV
# 203                       PHI                    DST9  DST11   PHI
# 189              Nico Collins                    WR60   WR61   HOU
# 200              Boston Scott                    RB67          PHI
# 193             Chuba Hubbard                    RB60   RB58   CAR
# 202                       MIA                    DST8  DST12   MIA
# 220           Isaiah McKenzie                           WR58  None
# 184               Gus Edwards                    RB56   RB60   BAL
# 201                        NE                    DST6  DST13    NE
# 176              Kenyan Drake                    RB52   RB65    LV
# 208               Matt Prater                      K9     K7   ARI
# 206           Brandon McManus                      K6     K8   DEN
# 221                 Cade York                            K10  None
# 204                       ARI                   DST10          ARI
# 205            Evan McPherson                      K1          CIN
# 222        Albert Okwuegbunam                           TE18  None
# 223                       DEN                          DST14   DEN
# 181            Kenny Golladay                    WR55   WR68   NYG
# 224               Greg Joseph                            K11  None
# 207                 Nick Folk                      K8    K12    NE
# 197            Hassan Haskins                    RB64   RB63   TEN
# 225            Dustin Hopkins                            K13  None
# 226                       CLE                          DST16   CLE
# 227       Rodrigo Blankenship                            K14  None
# 228                       BAL                          DST17   BAL
# 209              Younghoe Koo                     K10    K16   ATL
# 160            DeVante Parker           WR37            WR63    NE
# 199               Sony Michel                    RB66   RB67   MIA
# 229               Ryan Succop                            K15  None
# 230          Christian Watson                           WR64  None
# 231                  Wil Lutz                            K17  None
# 232          D'Ernest Johnson                           RB61  None
# 233          Jameson Williams                           WR66  None
# 234        Tyrion Davis-Price                           RB62  None
# 235             Rondale Moore                           WR67  None
# 236              Robbie Gould                            K18  None
# 237               Taysom Hill                           TE19  None
# 238              Hayden Hurst                           TE20  None
# 239              Kyle Rudolph                           TE21  None
# 240           Darrel Williams                           RB64  None
# 241              Tyler Higbee                           TE22  None
# 242               Trey Sermon                           RB66  None
# 243             Austin Hooper                           TE23  None
# 244             Sammy Watkins                           WR69  None
# 162             Odell Beckham           WR39                   LAR
#
#     f_team  f_pick
# 0      NaN     NaN
# 1      NaN     NaN
# 2      NaN     NaN
# 4      NaN     NaN
# 3      NaN     NaN
# 8      NaN     NaN
# 5      NaN     NaN
# 6      NaN     NaN
# 7      NaN     NaN
# 9      NaN     NaN
# 10     NaN     NaN
# 14     NaN     NaN
# 11     NaN     NaN
# 13     NaN     NaN
# 15     NaN     NaN
# 12     NaN     NaN
# 16      RK     1.0
# 20     NaN     NaN
# 17     NaN     NaN
# 19     NaN     NaN
# 18     NaN     NaN
# 25     NaN     NaN
# 22     NaN     NaN
# 21     NaN     NaN
# 27     NaN     NaN
# 26     NaN     NaN
# 30     NaN     NaN
# 31     NaN     NaN
# 33     NaN     NaN
# 24     NaN     NaN
# 23     NaN     NaN
# 29     NaN     NaN
# 35     NaN     NaN
# 34     NaN     NaN
# 36     NaN     NaN
# 32     NaN     NaN
# 37     NaN     NaN
# 28     NaN     NaN
# 41     NaN     NaN
# 38     NaN     NaN
# 42     NaN     NaN
# 40     NaN     NaN
# 39     NaN     NaN
# 45     NaN     NaN
# 47     NaN     NaN
# 52     NaN     NaN
# 46     NaN     NaN
# 50     NaN     NaN
# 48     NaN     NaN
# 57     NaN     NaN
# 43     NaN     NaN
# 49     NaN     NaN
# 44     NaN     NaN
# 51     NaN     NaN
# 55     NaN     NaN
# 53     NaN     NaN
# 56     NaN     NaN
# 69     NaN     NaN
# 54     NaN     NaN
# 60     NaN     NaN
# 59     NaN     NaN
# 58     NaN     NaN
# 66     NaN     NaN
# 63     NaN     NaN
# 61     NaN     NaN
# 73     NaN     NaN
# 65     NaN     NaN
# 62     NaN     NaN
# 77     NaN     NaN
# 70     NaN     NaN
# 64     NaN     NaN
# 71     NaN     NaN
# 68     NaN     NaN
# 85     NaN     NaN
# 75     NaN     NaN
# 78     NaN     NaN
# 72     NaN     NaN
# 81     NaN     NaN
# 76     NaN     NaN
# 83     NaN     NaN
# 67     NaN     NaN
# 86     NaN     NaN
# 82     NaN     NaN
# 74     NaN     NaN
# 84     NaN     NaN
# 95     NaN     NaN
# 93     NaN     NaN
# 87     NaN     NaN
# 80     NaN     NaN
# 91     NaN     NaN
# 98     NaN     NaN
# 94     NaN     NaN
# 88     NaN     NaN
# 79     NaN     NaN
# 101    NaN     NaN
# 90     NaN     NaN
# 92     NaN     NaN
# 102    NaN     NaN
# 110    NaN     NaN
# 122    NaN     NaN
# 89     NaN     NaN
# 104    NaN     NaN
# 97     NaN     NaN
# 108    NaN     NaN
# 115    NaN     NaN
# 100    NaN     NaN
# 103    NaN     NaN
# 99     NaN     NaN
# 159    NaN     NaN
# 107    NaN     NaN
# 105    NaN     NaN
# 114    NaN     NaN
# 113    NaN     NaN
# 112    NaN     NaN
# 106    NaN     NaN
# 96     NaN     NaN
# 125    NaN     NaN
# 109    NaN     NaN
# 126    NaN     NaN
# 118    NaN     NaN
# 111    NaN     NaN
# 124    NaN     NaN
# 117    NaN     NaN
# 121    NaN     NaN
# 119    NaN     NaN
# 167    NaN     NaN
# 127    NaN     NaN
# 116    NaN     NaN
# 130    NaN     NaN
# 168    NaN     NaN
# 131    NaN     NaN
# 140    NaN     NaN
# 128    NaN     NaN
# 123    NaN     NaN
# 120    NaN     NaN
# 139    NaN     NaN
# 137    NaN     NaN
# 166    NaN     NaN
# 141    NaN     NaN
# 142    NaN     NaN
# 129    NaN     NaN
# 135    NaN     NaN
# 132    NaN     NaN
# 165    NaN     NaN
# 146    NaN     NaN
# 149    NaN     NaN
# 157    NaN     NaN
# 153    NaN     NaN
# 144    NaN     NaN
# 133    NaN     NaN
# 145    NaN     NaN
# 138    NaN     NaN
# 143    NaN     NaN
# 152    NaN     NaN
# 136    NaN     NaN
# 172    NaN     NaN
# 148    NaN     NaN
# 151    NaN     NaN
# 173    NaN     NaN
# 134    NaN     NaN
# 163    NaN     NaN
# 170    NaN     NaN
# 185    NaN     NaN
# 158    NaN     NaN
# 210    NaN     NaN
# 175    NaN     NaN
# 179    NaN     NaN
# 180    NaN     NaN
# 211    NaN     NaN
# 212    NaN     NaN
# 147    NaN     NaN
# 150    NaN     NaN
# 182    NaN     NaN
# 183    NaN     NaN
# 171    NaN     NaN
# 213    NaN     NaN
# 177    NaN     NaN
# 169    NaN     NaN
# 154    NaN     NaN
# 164    NaN     NaN
# 214    NaN     NaN
# 186    NaN     NaN
# 156    NaN     NaN
# 155    NaN     NaN
# 215    NaN     NaN
# 174    NaN     NaN
# 194    NaN     NaN
# 216    NaN     NaN
# 190    NaN     NaN
# 192    NaN     NaN
# 217    NaN     NaN
# 191    NaN     NaN
# 178    NaN     NaN
# 187    NaN     NaN
# 195    NaN     NaN
# 196    NaN     NaN
# 161    NaN     NaN
# 188    NaN     NaN
# 218    NaN     NaN
# 219    NaN     NaN
# 198    NaN     NaN
# 203    NaN     NaN
# 189    NaN     NaN
# 200    NaN     NaN
# 193    NaN     NaN
# 202    NaN     NaN
# 220    NaN     NaN
# 184    NaN     NaN
# 201    NaN     NaN
# 176    NaN     NaN
# 208    NaN     NaN
# 206    NaN     NaN
# 221    NaN     NaN
# 204    NaN     NaN
# 205    NaN     NaN
# 222    NaN     NaN
# 223    NaN     NaN
# 181    NaN     NaN
# 224    NaN     NaN
# 207    NaN     NaN
# 197    NaN     NaN
# 225    NaN     NaN
# 226    NaN     NaN
# 227    NaN     NaN
# 228    NaN     NaN
# 209    NaN     NaN
# 160    NaN     NaN
# 199    NaN     NaN
# 229    NaN     NaN
# 230    NaN     NaN
# 231    NaN     NaN
# 232    NaN     NaN
# 233    NaN     NaN
# 234    NaN     NaN
# 235    NaN     NaN
# 236    NaN     NaN
# 237    NaN     NaN
# 238    NaN     NaN
# 239    NaN     NaN
# 240    NaN     NaN
# 241    NaN     NaN
# 242    NaN     NaN
# 243    NaN     NaN
# 244    NaN     NaN
# 162    NaN     NaN

# %%
# Find Player
find_player('McCaffrey')
# Out:
# Close Matches:
# ['Christian McCaffrey']
# Contains:
# ['Christian McCaffrey']

# %%
rk, jm1, es, ay, ka, bl, ng, rw, bm, jb, bd, jm2 = fteams

auto_mode(True)

pick_+=1
dft = selection(pick_, 'Christian McCaffrey', jm1)
dft.head(20)
# Out:
#      avg_rank ffc_rank rt_rank espn_rank ds_rank  pos  \
# 0         1.0        1       2         1       1   QB
# 1         2.7        2       7         4       2   RB
# 2         3.0        3       9         3       3   QB
# 4         4.0        5       1         2       5   QB
# 3         7.7        4      12        15       4   RB
# 8         7.7        9       3         5       9   WR
# 5         8.0        6      19        12       6   RB
# 6         8.3        7      10        11       7   RB
# 7         8.3        8       4         9       8   WR
# 9         8.7       10      20         6      10   QB
# 10       12.0       11      21        14      11   RB
# 14       12.0       15      17         7      14   QB
# 11       12.3       12      25        13      12   RB
# 13       13.0       14       5        10      15   WR
# 15       13.3       16      14         8      16   QB
# 12       15.0       13      24        19      13   QB
# 16       19.0       17      15        23      17   RB
# 20       19.7       21      22        17      21   QB
# 17       20.7       18      32        26      18   RB
# 19       22.3       20      28        27      20   WR
# 18       22.7       19      11        30      19   WR
# 25       23.3       26      13        16      28   QB
# 22       24.0       23      26        24      25   RB
# 21       25.3       22      54        32      22   TE
# 27       25.7       28      34        22      27   QB
# 26       27.0       27      29        28      26   WR
# 30       27.3       31      18        20      31   QB
# 31       28.3       32       6        21      32   QB
# 33       28.7       34                18      34   QB
# 24       29.0       25      16        39      23   RB
# 23       29.3       24      41        40      24   RB
# 29       29.7       30       8        29      30   WR
# 35       33.0       36      30        25      38   RB
# 34       34.3       35      49        33      35   TE
# 36       34.7       37      23        31      36   WR
# 32       36.3       33      47        43      33   RB
# 37       36.3       38                34      37   QB
# 28       36.7       29      36        52      29   RB
# 41       40.7       42                38      42   QB
# 38       41.7       39      35        47      39   WR
# 42       42.3       43      64        41      43   RB
# 40       42.7       41      48        46      41   WR
# 39       43.7       40      62        51      40   RB
# 45       45.3       46      51        44      46   TE
# 47       47.0       48      31        45      48   WR
# 52       47.3       53                36      53   QB
# 46       48.0       47      73        50      47   RB
# 50       48.3       51      52        42      52   RB
# 48       49.0       49      42        49      49   RB
# 57       50.3       58                35      58   QB
# 43       50.7       44      44        64      44   WR
# 49       51.7       50                54      51   QB
# 44       52.0       45      27        66      45   WR
# 51       55.0       52      56        63      50   RB
# 55       56.3       56      45        57      56   TE
# 53       57.7       54      39        65      54   WR
# 56       58.3       57      57        59      59   RB
# 69       59.0       70                37      70   QB
# 54       59.7       55      69        69      55   WR
# 60       60.0       61      68        58      61   TE
# 59       60.3       60      40        61      60   RB
# 58       61.0       59      37        67      57   WR
# 66       62.3       67                53      67   QB
# 63       62.7       64      43        62      62   RB
# 61       65.0       62      38        70      63   WR
# 73       65.3       74      33        48      74   WR
# 65       66.7       66      53        68      66   WR
# 62       69.7       63      55        82      64   WR
# 77       71.3       78      65        60      76   RB
# 70       72.3       71      82        75      71   RB
# 64       74.0       65      72        92      65   RB
# 71       74.7       72      61        80      72   WR
# 68       75.0       69      46        87      69   WR
# 85       76.3       86                56      87   QB
# 75       76.3       76      77        78      75   RB
# 78       80.7       79      83        83      80   WR
# 72       82.7       73      59       102      73   WR
# 81       83.3       82                84      84   WR
# 76       84.0       77                97      78   WR
# 83       84.0       84                85      83   WR
# 67       84.3       68      76       117      68   WR
# 86       84.3       87      84        77      89   RB
# 82       85.0       83      90        90      82   RB
# 74       85.7       75               105      77   TE
# 84       85.7       85      63        86      86   WR
# 95       87.7       96                72      95   QB
# 93       87.7       94                76      93   RB
# 87       88.0       88      80        88      88   RB
# 80       88.0       81               104      79   TE
# 91       88.3       92      75        79      94   WR
# 98       89.3       99                71      98   QB
# 94       90.0       95                        85   QB
# 88       90.7       89      92        93      90   RB
# 79       90.7       80      88       111      81   RB
# 101      91.7      102                73     100   QB
# 90       93.7       91                99      91   WR
# 92       96.7       93      79       101      96   WR
# 102      98.3      103                89     103   RB
# 110      98.7      111                74     111   QB
# 122      99.7      123                55     121   QB
# 89      100.0       90      85       118      92   WR
# 104     101.7      105      50        96     104   WR
# 97      102.3       98      89       110      99   RB
# 108     102.3      109      91        91     107   RB
# 115     104.3      116      74        81     116   WR
# 100     104.7      101      78       112     101   RB
# 103     105.3      104      60       106     106   WR
# 99      105.7      100               115     102   WR
# 159     106.0               66       103     109   TE
# 107     108.0      108                             TE
# 105     108.0      106      70       113     105   WR
# 114     108.7      115                94     117   QB
# 113     109.7      114      58       100     115   WR
# 112     111.3      113               109     112   RB
# 106     112.7      107               123     108   TE
# 96      113.0       97      93       145      97   TE
# 125     115.7      126                95     126   QB
# 109     117.0      110      95       131     110   RB
# 126     117.7      127                98     128   WR
# 118     118.0      119      86       116     119   WR
# 111     120.7      112      67       137     113   WR
# 124     120.7      125      98       114     123   RB
# 117     121.0      118               127     118   QB
# 121     121.7      122      99       119     124   WR
# 119     124.3      120               133     120   RB
# 167     126.0                        126           QB
# 127     126.3      128               121     130   WR
# 116     128.0      117               153     114   RB
# 130     129.0      131               124     132   TE
# 168     130.0                        130           QB
# 131     130.0      132               129     129   QB
# 140     130.0      141      71       107     142   WR
# 128     132.7      129               142     127   RB
# 123     133.3      124      81       154     122   RB
# 120     133.7      121               155     125  DST
# 139     134.0      140               125     137   TE
# 137     137.7      138               135     140   RB
# 166     138.5                        120     157   WR
# 141     139.0      142               136     139   RB
# 142     139.3      143               128     147   QB
# 129     140.3      130               160     131   WR
# 135     140.7      136               148     138   TE
# 132     140.7      133               156     133  DST
# 165     142.5                        108     177   WR
# 146     143.0      147               138     144   WR
# 149     143.0      150               144     135   RB
# 157     146.0      158                       134   QB
# 153     146.0      154               134     150   RB
# 144     146.5      145                       148   WR
# 133     147.0      134               171     136   WR
# 145     147.3      146               143     153   RB
# 138     147.3      139               157     146  DST
# 143     148.0      144                       152   WR
# 152     148.3      153               151     141   RB
# 136     150.7      137               170     145   RB
# 172     152.0                        141     163   RB
# 148     152.0      149                       155   RB
# 151     154.0      152                       156  DST
# 173     156.5                        146     167   TE
# 134     157.3      135               194     143    K
# 163     157.5               97       147     168   TE
# 170     159.0                        139     179   WR
# 185     159.5                        168     151   RB
# 158     160.5      159                       162   WR
# 210     161.0                                161   TE
# 175     161.0                        150     172   QB
# 179     161.0                        161           WR
# 180     163.0                        163           WR
# 211     164.0                                164   TE
# 212     165.0                                165  DST
# 147     165.0      148               193     154    K
# 150     165.0      151               195     149    K
# 182     165.0                        165           WR
# 183     166.0                        166           RB
# 171     166.0                        140     192   WR
# 213     166.0                                166  DST
# 177     166.0                        158     174  DST
# 169     166.5                        132     201   RB
# 154     166.7      155               187     158  DST
# 164     167.0              100       122     212   WR
# 214     169.0                                169    K
# 186     169.0                        169           RB
# 156     169.7      157               192     160    K
# 155     170.7      156               197     159    K
# 215     171.0                                171   WR
# 174     171.5                        149     194   QB
# 194     174.5                        179     170   RB
# 216     175.0                                175  DST
# 190     175.0                        175           WR
# 192     175.0                        177     173   WR
# 217     176.0                                176  DST
# 191     176.0                        176           WR
# 178     178.5                        159     198  DST
# 187     179.0                        172     186   WR
# 195     180.0                        180           RB
# 196     181.0                        181           RB
# 161     181.0               94       162     200   WR
# 188     181.5                        173     190   WR
# 218     182.0                                182   WR
# 219     183.0                                183    K
# 198     184.0                        183     185   RB
# 203     184.5                        189     180  DST
# 189     185.0                        174     196   WR
# 200     185.0                        185           RB
# 193     185.5                        178     193   RB
# 202     186.0                        188     184  DST
# 220     187.0                                187   WR
# 184     187.0                        167     207   RB
# 201     187.0                        186     188  DST
# 176     188.0                        152     224   RB
# 208     188.5                        199     178    K
# 206     188.5                        196     181    K
# 221     189.0                                189    K
# 204     190.0                        190          DST
# 205     191.0                        191            K
# 222     191.0                                191   TE
# 223     195.0                                195  DST
# 181     195.0                        164     226   WR
# 224     197.0                                197    K
# 207     198.5                        198     199    K
# 197     199.5                        182     217   RB
# 225     202.0                                202    K
# 226     203.0                                203  DST
# 227     204.0                                204    K
# 228     205.0                                205  DST
# 209     205.0                        200     210    K
# 160     206.0               87               206   WR
# 199     206.0                        184     228   RB
# 229     208.0                                208    K
# 230     209.0                                209   WR
# 231     211.0                                211    K
# 232     213.0                                213   RB
# 233     214.0                                214   WR
# 234     215.0                                215   RB
# 235     216.0                                216   WR
# 236     218.0                                218    K
# 237     219.0                                219   TE
# 238     220.0                                220   TE
# 239     221.0                                221   TE
# 240     222.0                                222   RB
# 241     223.0                                223   TE
# 242     225.0                                225   RB
# 243     227.0                                227   TE
# 244     229.0                                229   WR
# 162       NaN               96                     WR
#
#                          name ffc_pos rt_pos espn_pos ds_pos  team bye_week  \
# 0                  Josh Allen     QB1    QB2      QB1    QB1   BUF        7
# 1             Jonathan Taylor     RB1    RB1      RB1    RB1   IND       14
# 2              Justin Herbert     QB2    QB4      QB3    QB2   LAC        8
# 4             Patrick Mahomes     QB3    QB1      QB2    QB3    KC        8
# 3         Christian McCaffrey     RB2    RB3      RB6    RB2   CAR       13
# 8                 Cooper Kupp     WR2    WR1      WR1    WR2   LAR        7
# 5               Derrick Henry     RB3    RB6      RB3    RB3   TEN        6
# 6               Austin Ekeler     RB4    RB2      RB2    RB4   LAC        8
# 7            Justin Jefferson     WR1    WR2      WR2    WR1   MIN        7
# 9               Lamar Jackson     QB4    QB9      QB4    QB4   BAL       10
# 10               Najee Harris     RB5    RB7      RB5    RB5   PIT        9
# 14               Kyler Murray     QB6    QB7      QB5    QB6   ARI       13
# 11                Dalvin Cook     RB6    RB8      RB4    RB6   MIN        7
# 13              Ja'Marr Chase     WR3    WR3      WR3    WR3   CIN       10
# 15                Jalen Hurts     QB7    QB6      QB6    QB7   PHI        7
# 12                 Joe Burrow     QB5   QB11     QB10    QB5   CIN       10
# 16                  Joe Mixon     RB7    RB4      RB7    RB7   CIN       10
# 20             Russell Wilson     QB8   QB10      QB8    QB8   DEN        9
# 17              D'Andre Swift     RB8   RB11     RB10    RB8   DET        6
# 19               Stefon Diggs     WR5    WR8      WR4    WR5   BUF        7
# 18              Davante Adams     WR4    WR5      WR7    WR4    LV        6
# 25                  Tom Brady     QB9    QB5      QB7   QB10    TB       11
# 22               Alvin Kamara     RB9    RB9      RB8   RB11    NO       14
# 21               Travis Kelce     TE1    TE4      TE1    TE1    KC        8
# 27           Matthew Stafford    QB10   QB12     QB13    QB9   LAR        7
# 26                CeeDee Lamb     WR6    WR9      WR5    WR6   DAL        9
# 30               Dak Prescott    QB11    QB8     QB11   QB11   DAL        9
# 31              Aaron Rodgers    QB12    QB3     QB12   QB12    GB       14
# 33                 Trey Lance    QB13             QB9   QB13    SF        9
# 24                 Nick Chubb    RB11    RB5     RB11    RB9   CLE        9
# 23                Aaron Jones    RB10   RB14     RB12   RB10    GB       14
# 29               Deebo Samuel     WR7    WR4      WR6    WR7    SF        9
# 35           Javonte Williams    RB14   RB10      RB9   RB14   DEN        9
# 34               Mark Andrews     TE2    TE2      TE2    TE2   BAL       10
# 36                Tyreek Hill     WR8    WR6      WR8    WR8   MIA       11
# 32          Leonard Fournette    RB13   RB17     RB15   RB13    TB       11
# 37                 Derek Carr    QB14            QB14   QB14    LV        6
# 28             Saquon Barkley    RB12   RB12     RB19   RB12   NYG        9
# 41               Kirk Cousins    QB15            QB18   QB15   MIN        7
# 38                 Mike Evans     WR9   WR12     WR11    WR9    TB       11
# 42               James Conner    RB16   RB22     RB13   RB16   ARI       13
# 40               Keenan Allen    WR10   WR18     WR10   WR10   LAC        8
# 39            Ezekiel Elliott    RB15   RB21     RB18   RB15   DAL        9
# 45                 Kyle Pitts     TE3    TE3      TE3    TE3   ATL       14
# 47                Tee Higgins    WR13   WR10      WR9   WR13   CIN       10
# 52             Tua Tagovailoa    QB17            QB16   QB17   MIA       11
# 46             Travis Etienne    RB17   RB26     RB17   RB17   JAX       11
# 50                  Cam Akers    RB19   RB18     RB14   RB20   LAR        7
# 48           David Montgomery    RB18   RB15     RB16   RB18   CHI       14
# 57            Trevor Lawrence    QB18            QB15   QB18   JAX       11
# 43            Michael Pittman    WR11   WR16     WR13   WR11   IND       14
# 49                  Matt Ryan    QB16            QB20   QB16   IND       14
# 44                   AJ Brown    WR12    WR7     WR15   WR12   PHI        7
# 51                 JK Dobbins    RB20   RB19     RB24   RB19   BAL       10
# 55              George Kittle     TE4    TE1      TE4    TE4    SF        9
# 53             Terry McLaurin    WR14   WR15     WR14   WR14   WAS       14
# 56                Breece Hall    RB21   RB20     RB20   RB21   NYJ       10
# 69              Justin Fields    QB20            QB17   QB20   CHI       14
# 54              Mike Williams    WR15   WR28     WR18   WR15   LAC        8
# 60              Darren Waller     TE5    TE6      TE5    TE5    LV        6
# 59            Elijah Mitchell    RB22   RB13     RB22   RB22    SF        9
# 58                 DK Metcalf    WR16   WR13     WR16   WR16   SEA       11
# 66             Jameis Winston    QB19            QB19   QB19    NO       14
# 63                Josh Jacobs    RB23   RB16     RB23   RB23    LV        6
# 61            Diontae Johnson    WR17   WR14     WR19   WR17   PIT        9
# 73                   DJ Moore    WR24   WR11     WR12   WR24   CAR       13
# 65              Jaylen Waddle    WR19   WR20     WR17   WR19   MIA       11
# 62           Courtland Sutton    WR18   WR21     WR23   WR18   DEN        9
# 77             Antonio Gibson    RB27   RB23     RB21   RB27   WAS       14
# 70      Clyde Edwards-Helaire    RB25   RB31     RB25   RB25    KC        8
# 64                  AJ Dillon    RB24   RB25     RB33   RB24    GB       14
# 71              Brandin Cooks    WR22   WR25     WR21   WR22   HOU        6
# 68               Chris Godwin    WR21   WR17     WR28   WR21    TB       11
# 85             Ryan Tannehill    QB21            QB22   QB22   TEN        6
# 75              Miles Sanders    RB26   RB27     RB28   RB26   PHI        7
# 78                Jerry Jeudy    WR26   WR34     WR24   WR26   DEN        9
# 72             Allen Robinson    WR23   WR23     WR35   WR23   LAR        7
# 81              Gabriel Davis    WR27            WR25   WR28   BUF        7
# 76               Adam Thielen    WR25            WR30   WR25   MIN        7
# 83             Darnell Mooney    WR28            WR26   WR27   CHI       14
# 67             Michael Thomas    WR20   WR32     WR41   WR20    NO       14
# 86                Kareem Hunt    RB30   RB32     RB27   RB31   CLE        9
# 82               Tony Pollard    RB29   RB35     RB31   RB29   DAL        9
# 74             Dalton Schultz     TE6             TE8    TE6   DAL        9
# 84             Marquise Brown    WR29   WR26     WR27   WR29   ARI       13
# 95               Daniel Jones    QB23            QB24   QB23   NYG        9
# 93           Devin Singletary    RB33            RB26   RB33   BUF        7
# 87              Damien Harris    RB31   RB29     RB29   RB30    NE       10
# 80               TJ Hockenson     TE7             TE7    TE7   DET        6
# 91           Amon-Ra St Brown    WR32   WR31     WR20   WR32   DET        6
# 98                  Mac Jones    QB24            QB23   QB24    NE       10
# 94             Deshaun Watson    QB22                   QB21   CLE        9
# 88              Chase Edmonds    RB32   RB37     RB34   RB32   MIA       11
# 79              Rashaad Penny    RB28   RB33     RB37   RB28   SEA       11
# 101              Carson Wentz    QB25            QB25   QB25   WAS       14
# 90             Hunter Renfrow    WR31            WR32   WR30    LV        6
# 92        JuJu Smith-Schuster    WR33   WR33     WR34   WR33    KC        8
# 102             Dameon Pierce    RB36            RB30   RB36   HOU        6
# 110                Jared Goff    QB26            QB26   QB26   DET        6
# 122               Zach Wilson    QB29            QB21   QB29   NYJ       10
# 89            DeAndre Hopkins    WR30   WR35     WR42   WR31   ARI       13
# 104              Amari Cooper    WR36   WR19     WR29   WR35   CLE        9
# 97        Rhamondre Stevenson    RB34   RB34     RB36   RB34    NE       10
# 108             Melvin Gordon    RB37   RB36     RB32   RB38   DEN        9
# 115              Elijah Moore    WR40   WR30     WR22   WR39   NYJ       10
# 100            Kenneth Walker    RB35   RB28     RB38   RB35   SEA       11
# 103            Rashod Bateman    WR35   WR24     WR36   WR36   BAL       10
# 99               Allen Lazard    WR34            WR39   WR34    GB       14
# 159            Dallas Goedert            TE5      TE6   TE10   PHI
# 107               DAL Goedert    TE10                          PHI        7
# 105     Cordarrelle Patterson    WR37   RB24     RB39   RB37   ATL       14
# 114            Baker Mayfield    QB27            QB27   QB27   CAR       13
# 113             DeVonta Smith    WR39   WR22     WR33   WR38   PHI        7
# 112            James Robinson    RB39            RB35   RB40   JAX       11
# 106                 Zach Ertz     TE9             TE9    TE9   ARI       13
# 96                Dawson Knox     TE8    TE7     TE12    TE8   BUF        7
# 125               Davis Mills    QB30            QB28   QB30   HOU        6
# 109                James Cook    RB38   RB38     RB41   RB39   BUF        7
# 126            Christian Kirk    WR43            WR31   WR42   JAX       11
# 118              Robert Woods    WR41   WR36     WR40   WR40   TEN        6
# 111             Brandon Aiyuk    WR38   WR27     WR47   WR37    SF        9
# 124            Michael Carter    RB43   RB39     RB40   RB44   NYJ       10
# 117            Marcus Mariota    QB28            QB30   QB28   ATL       14
# 121              Drake London    WR42   WR40     WR43   WR41   ATL       14
# 119              Nyheim Hines    RB41            RB43   RB42   IND       14
# 167                 Drew Lock                    QB29          SEA
# 127               Chris Olave    WR44            WR45   WR43    NO       14
# 116        Alexander Mattison    RB40            RB53   RB41   MIN        7
# 130            Pat Freiermuth    TE11            TE10   TE11   PIT        9
# 168            Desmond Ridder                    QB33          ATL
# 131            Mitch Trubisky    QB31            QB32   QB31   PIT        9
# 140             Tyler Lockett    WR47   WR29     WR37   WR46   SEA       11
# 128            Tyler Allgeier    RB44            RB48   RB45   ATL       14
# 123         Darrell Henderson    RB42   RB30     RB54   RB43   LAR        7
# 120                       BUF    DST1            DST1   DST1   BUF        7
# 139              Mike Gesicki    TE13            TE11   TE12   MIA       11
# 137            Raheem Mostert    RB46            RB45   RB48   MIA       11
# 166             Treylon Burks                    WR44   WR50   TEN
# 141            Isaiah Spiller    RB47            RB46   RB47   LAC        8
# 142             Kenny Pickett    QB32            QB31   QB33   PIT        9
# 129            Kadarius Toney    WR45            WR51   WR44   NYG        9
# 135                 Cole Kmet    TE12            TE15   TE13   CHI       14
# 132                        TB    DST2            DST2   DST2    TB       11
# 165            Chase Claypool                    WR38   WR54   PIT
# 146              Russell Gage    WR50            WR48   WR47    TB       11
# 149              Ronald Jones    RB50            RB50   RB46    KC        8
# 157           Jimmy Garoppolo    QB33                   QB32    SF        9
# 153               JD McKissic    RB52            RB44   RB51   WAS       14
# 144            Michael Gallup    WR49                   WR48   DAL        9
# 133                Skyy Moore    WR46            WR57   WR45    KC        8
# 145          Kenneth Gainwell    RB48            RB49   RB53   PHI        7
# 138                       LAR    DST3            DST3   DST3   LAR        7
# 143            George Pickens    WR48                   WR49   PIT        9
# 152               Marlon Mack    RB51            RB51   RB49   HOU        6
# 136            Brian Robinson    RB45            RB59   RB50   WAS       14
# 172             Rachaad White                    RB47   RB55    TB
# 148             Isiah Pacheco    RB49                   RB54    KC        8
# 151                        SF    DST4                   DST4    SF        9
# 173                 Irv Smith                    TE13   TE16   MIN
# 134             Justin Tucker      K1              K4     K1   BAL       10
# 163              Hunter Henry            TE8     TE14   TE17    NE
# 170  Marquez Valdes-Scantling                    WR49   WR55    KC
# 185               Mark Ingram                    RB57   RB52    NO
# 158               Julio Jones    WR51                   WR51    TB       11
# 210               David Njoku                           TE14  None
# 175           Jacoby Brissett                    QB35   QB34   CLE
# 179             Jakobi Meyers                    WR52           NE
# 180           Robbie Anderson                    WR54          CAR
# 211             Robert Tonyan                           TE15  None
# 212                       DAL                           DST6   DAL
# 147           Harrison Butker      K2              K3     K3    KC        8
# 150                Tyler Bass      K3              K5     K2   BUF        7
# 182           Marvin Jones Jr                    WR56          JAX
# 183           Damien Williams                    RB55          ATL
# 171            Mecole Hardman                    WR50   WR60    KC
# 213                       IND                           DST7   IND
# 177                        NO                    DST4   DST8    NO
# 169           Jamaal Williams                    RB42   RB59   DET
# 154                       PIT    DST5            DST7   DST5   PIT        9
# 164            Garrett Wilson           WR41     WR46   WR65   NYJ
# 214             Chris Boswell                             K6  None
# 186            Khalil Herbert                    RB58          CHI
# 156                  Matt Gay      K5              K2     K5   LAR        7
# 155            Daniel Carlson      K4              K7     K4    LV        6
# 215               Romeo Doubs                           WR52  None
# 174                Geno Smith                    QB34   QB35   SEA
# 194            D'Onta Foreman                    RB61   RB56   CAR
# 216                       WAS                           DST9   WAS
# 190             Van Jefferson                    WR61          LAR
# 192                  DJ Chark                    WR63   WR53   DET
# 217                       LAC                          DST10   LAC
# 191             Joshua Palmer                    WR62          LAC
# 178                        GB                    DST5  DST15    GB
# 187              Jahan Dotson                    WR58   WR57   WSH
# 195              Rex Burkhead                    RB62          HOU
# 196                Mike Davis                    RB63          BAL
# 161                Tyler Boyd           WR38     WR53   WR62   CIN
# 188             Jarvis Landry                    WR59   WR59    NO
# 218             Jalen Tolbert                           WR56  None
# 219             Jason Sanders                             K9  None
# 198               Zamir White                    RB65   RB57    LV
# 203                       PHI                    DST9  DST11   PHI
# 189              Nico Collins                    WR60   WR61   HOU
# 200              Boston Scott                    RB67          PHI
# 193             Chuba Hubbard                    RB60   RB58   CAR
# 202                       MIA                    DST8  DST12   MIA
# 220           Isaiah McKenzie                           WR58  None
# 184               Gus Edwards                    RB56   RB60   BAL
# 201                        NE                    DST6  DST13    NE
# 176              Kenyan Drake                    RB52   RB65    LV
# 208               Matt Prater                      K9     K7   ARI
# 206           Brandon McManus                      K6     K8   DEN
# 221                 Cade York                            K10  None
# 204                       ARI                   DST10          ARI
# 205            Evan McPherson                      K1          CIN
# 222        Albert Okwuegbunam                           TE18  None
# 223                       DEN                          DST14   DEN
# 181            Kenny Golladay                    WR55   WR68   NYG
# 224               Greg Joseph                            K11  None
# 207                 Nick Folk                      K8    K12    NE
# 197            Hassan Haskins                    RB64   RB63   TEN
# 225            Dustin Hopkins                            K13  None
# 226                       CLE                          DST16   CLE
# 227       Rodrigo Blankenship                            K14  None
# 228                       BAL                          DST17   BAL
# 209              Younghoe Koo                     K10    K16   ATL
# 160            DeVante Parker           WR37            WR63    NE
# 199               Sony Michel                    RB66   RB67   MIA
# 229               Ryan Succop                            K15  None
# 230          Christian Watson                           WR64  None
# 231                  Wil Lutz                            K17  None
# 232          D'Ernest Johnson                           RB61  None
# 233          Jameson Williams                           WR66  None
# 234        Tyrion Davis-Price                           RB62  None
# 235             Rondale Moore                           WR67  None
# 236              Robbie Gould                            K18  None
# 237               Taysom Hill                           TE19  None
# 238              Hayden Hurst                           TE20  None
# 239              Kyle Rudolph                           TE21  None
# 240           Darrel Williams                           RB64  None
# 241              Tyler Higbee                           TE22  None
# 242               Trey Sermon                           RB66  None
# 243             Austin Hooper                           TE23  None
# 244             Sammy Watkins                           WR69  None
# 162             Odell Beckham           WR39                   LAR
#
#     f_team  f_pick
# 0       RK     2.0
# 1      NaN     NaN
# 2      NaN     NaN
# 4      NaN     NaN
# 3      1.0     4.0
# 8      NaN     NaN
# 5      NaN     NaN
# 6      NaN     NaN
# 7      NaN     NaN
# 9      NaN     NaN
# 10     NaN     NaN
# 14     NaN     NaN
# 11     NaN     NaN
# 13     NaN     NaN
# 15     NaN     NaN
# 12     NaN     NaN
# 16     NaN     NaN
# 20     NaN     NaN
# 17     NaN     NaN
# 19     NaN     NaN
# 18     NaN     NaN
# 25     NaN     NaN
# 22     NaN     NaN
# 21     NaN     NaN
# 27     NaN     NaN
# 26     NaN     NaN
# 30     NaN     NaN
# 31     NaN     NaN
# 33     NaN     NaN
# 24     NaN     NaN
# 23     NaN     NaN
# 29     NaN     NaN
# 35     NaN     NaN
# 34     NaN     NaN
# 36     NaN     NaN
# 32     NaN     NaN
# 37     NaN     NaN
# 28     NaN     NaN
# 41     NaN     NaN
# 38     NaN     NaN
# 42     NaN     NaN
# 40     NaN     NaN
# 39     NaN     NaN
# 45     NaN     NaN
# 47     NaN     NaN
# 52     NaN     NaN
# 46     NaN     NaN
# 50     NaN     NaN
# 48     NaN     NaN
# 57     NaN     NaN
# 43     NaN     NaN
# 49     NaN     NaN
# 44     NaN     NaN
# 51     NaN     NaN
# 55     NaN     NaN
# 53     NaN     NaN
# 56     NaN     NaN
# 69     NaN     NaN
# 54     NaN     NaN
# 60     NaN     NaN
# 59     NaN     NaN
# 58     NaN     NaN
# 66     NaN     NaN
# 63     NaN     NaN
# 61     NaN     NaN
# 73     NaN     NaN
# 65     NaN     NaN
# 62     NaN     NaN
# 77     NaN     NaN
# 70     NaN     NaN
# 64     NaN     NaN
# 71     NaN     NaN
# 68     NaN     NaN
# 85     NaN     NaN
# 75     NaN     NaN
# 78     NaN     NaN
# 72     NaN     NaN
# 81     NaN     NaN
# 76     NaN     NaN
# 83     NaN     NaN
# 67     NaN     NaN
# 86     NaN     NaN
# 82     NaN     NaN
# 74     NaN     NaN
# 84     NaN     NaN
# 95     NaN     NaN
# 93     NaN     NaN
# 87     NaN     NaN
# 80     NaN     NaN
# 91     NaN     NaN
# 98     NaN     NaN
# 94     NaN     NaN
# 88     NaN     NaN
# 79     NaN     NaN
# 101    NaN     NaN
# 90     NaN     NaN
# 92     NaN     NaN
# 102    NaN     NaN
# 110    NaN     NaN
# 122    NaN     NaN
# 89     NaN     NaN
# 104    NaN     NaN
# 97     NaN     NaN
# 108    NaN     NaN
# 115    NaN     NaN
# 100    NaN     NaN
# 103    NaN     NaN
# 99     NaN     NaN
# 159    NaN     NaN
# 107    NaN     NaN
# 105    NaN     NaN
# 114    NaN     NaN
# 113    NaN     NaN
# 112    NaN     NaN
# 106    NaN     NaN
# 96     NaN     NaN
# 125    NaN     NaN
# 109    NaN     NaN
# 126    NaN     NaN
# 118    NaN     NaN
# 111    NaN     NaN
# 124    NaN     NaN
# 117    NaN     NaN
# 121    NaN     NaN
# 119    NaN     NaN
# 167    NaN     NaN
# 127    NaN     NaN
# 116    NaN     NaN
# 130    NaN     NaN
# 168    NaN     NaN
# 131    NaN     NaN
# 140    NaN     NaN
# 128    NaN     NaN
# 123    NaN     NaN
# 120    NaN     NaN
# 139    NaN     NaN
# 137    NaN     NaN
# 166    NaN     NaN
# 141    NaN     NaN
# 142    NaN     NaN
# 129    NaN     NaN
# 135    NaN     NaN
# 132    NaN     NaN
# 165    NaN     NaN
# 146    NaN     NaN
# 149    NaN     NaN
# 157    NaN     NaN
# 153    NaN     NaN
# 144    NaN     NaN
# 133    NaN     NaN
# 145    NaN     NaN
# 138    NaN     NaN
# 143    NaN     NaN
# 152    NaN     NaN
# 136    NaN     NaN
# 172    NaN     NaN
# 148    NaN     NaN
# 151    NaN     NaN
# 173    NaN     NaN
# 134    NaN     NaN
# 163    NaN     NaN
# 170    NaN     NaN
# 185    NaN     NaN
# 158    NaN     NaN
# 210    NaN     NaN
# 175    NaN     NaN
# 179    NaN     NaN
# 180    NaN     NaN
# 211    NaN     NaN
# 212    NaN     NaN
# 147    NaN     NaN
# 150    NaN     NaN
# 182    NaN     NaN
# 183    NaN     NaN
# 171    NaN     NaN
# 213    NaN     NaN
# 177    NaN     NaN
# 169    NaN     NaN
# 154    NaN     NaN
# 164    NaN     NaN
# 214    NaN     NaN
# 186    NaN     NaN
# 156    NaN     NaN
# 155    NaN     NaN
# 215    NaN     NaN
# 174    NaN     NaN
# 194    NaN     NaN
# 216    NaN     NaN
# 190    NaN     NaN
# 192    NaN     NaN
# 217    NaN     NaN
# 191    NaN     NaN
# 178    NaN     NaN
# 187    NaN     NaN
# 195    NaN     NaN
# 196    NaN     NaN
# 161    NaN     NaN
# 188    NaN     NaN
# 218    NaN     NaN
# 219    NaN     NaN
# 198    NaN     NaN
# 203    NaN     NaN
# 189    NaN     NaN
# 200    NaN     NaN
# 193    NaN     NaN
# 202    NaN     NaN
# 220    NaN     NaN
# 184    NaN     NaN
# 201    NaN     NaN
# 176    NaN     NaN
# 208    NaN     NaN
# 206    NaN     NaN
# 221    NaN     NaN
# 204    NaN     NaN
# 205    NaN     NaN
# 222    NaN     NaN
# 223    NaN     NaN
# 181    NaN     NaN
# 224    NaN     NaN
# 207    NaN     NaN
# 197    NaN     NaN
# 225    NaN     NaN
# 226    NaN     NaN
# 227    NaN     NaN
# 228    NaN     NaN
# 209    NaN     NaN
# 160    NaN     NaN
# 199    NaN     NaN
# 229    NaN     NaN
# 230    NaN     NaN
# 231    NaN     NaN
# 232    NaN     NaN
# 233    NaN     NaN
# 234    NaN     NaN
# 235    NaN     NaN
# 236    NaN     NaN
# 237    NaN     NaN
# 238    NaN     NaN
# 239    NaN     NaN
# 240    NaN     NaN
# 241    NaN     NaN
# 242    NaN     NaN
# 243    NaN     NaN
# 244    NaN     NaN
# 162    NaN     NaN
